# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

# Google API Key
from config import gkey

# %%
wine_df = pd.read_csv("wine_reviews_kaggle.csv")
wine_df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
wine_df.count()
# Out:
# Unnamed: 0               129652
# country                  129589
# description              129652
# designation               92309
# points                   129652
# price                    120656
# province                 129589
# region_1                 108465
# region_2                  50490
# taster_name              103439
# taster_twitter_handle     98493
# title                    129652
# variety                  129651
# winery                   129652
# dtype: int64

# %%
# wine_df = wine_df.dropna(how='any')

# %%
wine_df.count()
# Out:
# Unnamed: 0               129652
# country                  129589
# description              129652
# designation               92309
# points                   129652
# price                    120656
# province                 129589
# region_1                 108465
# region_2                  50490
# taster_name              103439
# taster_twitter_handle     98493
# title                    129652
# variety                  129651
# winery                   129652
# dtype: int64

# %%
wine_df.dtypes
# Out:
# Unnamed: 0                 int64
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
wine_df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
wine_df = wine_df.loc[(wine_df["price"] < 300)]

# Set the index of this new dataframe to be the wrestlers names
wine_df = wine_df.set_index("Unnamed: 0")

# %%
wine_df["province"].value_counts()
# Out:
# California                   36078
# Washington                    8583
# Oregon                        5359
# Tuscany                       5096
# Bordeaux                      3952
# Northern Spain                3782
# Mendoza Province              3226
# Piedmont                      3075
# Burgundy                      3008
# New York                      2676
# Veneto                        2308
# Alsace                        2147
# Northeastern Italy            1986
# Loire Valley                  1597
# Sicily & Sardinia             1558
# Champagne                     1353
# Southwest France              1334
# South Australia               1324
# Catalonia                     1152
# Provence                      1139
# Douro                         1132
# Southern Italy                1131
# Central Italy                 1099
# Rhône Valley                  1040
# Mosel                         1015
# Beaujolais                     846
# Alentejano                     821
# ...

# %%
wine_df.nunique()
# Out:
# country                      42
# description              111219
# designation               35685
# points                       21
# price                       260
# province                    422
# region_1                   1194
# region_2                     17
# taster_name                  19
# taster_twitter_handle        15
# title                    110302
# variety                     535
# winery                    15840
# dtype: int64

# %%
 from sqlalchemy import create_engine
engine = create_engine('sqlite://', echo=False)

# %%
wine_df.to_json("wine_clean.json")

# %%
winejson_df = pd.read_json("wine_clean.json")
winejson_df.head()
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 10            US  Soft, supple plum envelopes an oaky structure ...
# 100           US  Fresh apple, lemon and pear flavors are accent...
# 1000          US  Arcane's Cab is stylistically apart from eithe...
# 100000        US  Creamy black cherry aromas layered with fresh ...
#
#            designation  points  price    province      region_1  \
# 1             Avidagos      87     15       Douro          None
# 10      Mountain Cuvée      87     19  California   Napa Valley
# 100               None      88     18    New York  Finger Lakes
# 1000              None      88     24      Oregon  Rogue Valley
# 100000            None      89     70  California   Napa Valley
#
#                region_2         taster_name taster_twitter_handle  \
# 1                  None          Roger Voss            @vossroger
# ...

# %%
wine_df.to_csv("wine_clean.csv")

# %%
wine_csv = pd.read_csv("wine_clean.csv")
wine_csv.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 1           2        US  Tart and snappy, the flavors of lime flesh and...
# 2           3        US  Pineapple rind, lemon pith and orange blossom ...
# 3           4        US  Much like the regular bottling from 2012, this...
# 4           5     Spain  Blackberry and raspberry aromas show a typical...
#
#                           designation  points  price        province  \
# 0                            Avidagos      87   15.0           Douro
# 1                                 NaN      87   14.0          Oregon
# 2                Reserve Late Harvest      87   13.0        Michigan
# 3  Vintner's Reserve Wild Child Block      87   65.0          Oregon
# 4                        Ars In Vitro      87   15.0  Northern Spain
#
#               region_1           region_2         taster_name  \
# ...

# %%
us_wine_df = wine_df.loc[(wine_df["province"] == "Washington Oregan"

# Set the index of this new dataframe to be the wrestlers names
# us_wine_df = us_wine_df.set_index("Unnamed: 0")

us_wine_df.head()
# Out:
#   File "<ipython-input-23-8d6dd594db47>", line 6
#     us_wine_df.head()
#              ^
# SyntaxError: invalid syntax

# %%
# us_wine_df["Lat"] = ""
# us_wine_df["Lng"] = ""
# us_wine_df.head()

# us_wine_df.rename(columns={"province" : "State"})

# %%
# create a params dict that will be updated with new city each iteration
# params = {"key": gkey}
# number = 0
# # Loop through the cities_pd and run a lat/long search for each city
# for index, row in us_wine_df.iterrows():
#     number = number + 1
#     base_url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json?"
    
# https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input=Museum%20of%20Contemporary%20Art%20Australia&inputtype=textquery&fields=photos,formatted_address,name,rating,opening_hours,geometry&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y
    
#     https://maps.googleapis.com/maps/api/place/findplacefromtext/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&input=Sweet%20Cheeks%20winery
    
    
#     winery = row['winery']

#     # update address key value
#     params['input'] = f"{winery} winery"

#     # make request, print url
#     winery_lat_lng = requests.get(base_url, params=params)
#     print(winery_lat_lng.url)
#     # convert to json
#     winery_lat_lng = winery_lat_lng.json()

# #     us_wine_df.loc[index, "Lat"] = winery_lat_lng["results"][0]["geometry"]["location"]["lat"]
# #     us_wine_df.loc[index, "Lng"] = winery_lat_lng["results"][0]["geometry"]["location"]["lng"]
    
#     if number == 5:
#       break 
    
# # Visualize to confirm lat lng appear
# us_wine_df.head()

# %%
# https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input=Museum%20of%20Contemporary%20Art%20Australia&inputtype=textquery&fields=photos,formatted_address,name,rating,opening_hours,geometry&key=YOUR_API_KEY

# %%
#count 
# total_unique_wines = wine_df["variety"].nunique()

# #create total players dataframe
# total_wine_df = pd.DataFrame({"Total Reviews" : [total_unique_wines]})

# #display dataframe
# total_wine_df

# %%
#variable to hold unique count of Item ID
# unique_wines = wine_df["variety"].nunique()

# #variable to hold mean value of Price
# average_price = wine_df["price"].mean()

# #variable to hold count of Item ID
# average_points = wine_df["points"].mean()

# #creates dataframe that combines the above variables 
# wine_analysis_df = pd.DataFrame({"Variety_count" : [unique_items]
#                                      ,"Average Price" : [average_price]
#                                      ,"Average Points" : [total_purchases]
#                                      })
# #format Average Price to currency
# wine_analysis_df["Average Price"] = purchase_analysis_df["Average Price"].map("${:,.2f}".format)

# #format Total Revenue to currency
# purchase_analysis_df["Total Revenue"] = purchase_analysis_df["Total Revenue"].map("${:,.2f}".format)

# #order the columns in the dataframe
# purchase_analysis_df = purchase_analysis_df[["Number of Unique Items", "Average Price", "Number of Purchases", "Total Revenue"]]

# #display dataframe
# purchase_analysis_df
